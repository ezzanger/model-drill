# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.mlab import PCA as mlabPCA
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2


import matplotlib.ticker as mtick
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats
sns.set_style("whitegrid")

hate = pd.read_csv('/Users/ezzan/Downloads/hate_crimes.csv')
hate = hate[hate.state != 'District of Columbia']

# %%
hate.head(50)
# Out:
#              state  median_household_income  share_unemployed_seasonal  \
# 0          Alabama                    42278                      0.060
# 1           Alaska                    67629                      0.064
# 2          Arizona                    49254                      0.063
# 3         Arkansas                    44922                      0.052
# 4       California                    60487                      0.059
# 5         Colorado                    60940                      0.040
# 6      Connecticut                    70161                      0.052
# 7         Delaware                    57522                      0.049
# 9          Florida                    46140                      0.052
# 10         Georgia                    49555                      0.058
# 11          Hawaii                    71223                      0.034
# 12           Idaho                    53438                      0.042
# 13        Illinois                    54916                      0.054
# 14         Indiana                    48060                      0.044
# 15            Iowa                    57810                      0.036
# 16          Kansas                    53444                      0.044
# 17        Kentucky                    42786                      0.050
# 18       Louisiana                    42406                      0.060
# 19           Maine                    51710                      0.044
# 20        Maryland                    76165                      0.051
# 21   Massachusetts                    63151                      0.046
# 22        Michigan                    52005                      0.050
# 23       Minnesota                    67244                      0.038
# 24     Mississippi                    35521                      0.061
# 25        Missouri                    56630                      0.053
# 26         Montana                    51102                      0.041
# 27        Nebraska                    56870                      0.029
# 28          Nevada                    49875                      0.067
# 29   New Hampshire                    73397                      0.034
# 30      New Jersey                    65243                      0.056
# 31      New Mexico                    46686                      0.068
# 32        New York                    54310                      0.051
# 33  North Carolina                    46784                      0.058
# 34    North Dakota                    60730                      0.028
# 35            Ohio                    49644                      0.045
# 36        Oklahoma                    47199                      0.044
# 37          Oregon                    58875                      0.062
# 38    Pennsylvania                    55173                      0.053
# 39    Rhode Island                    58633                      0.054
# 40  South Carolina                    44929                      0.057
# 41    South Dakota                    53053                      0.035
# 42       Tennessee                    43716                      0.057
# 43           Texas                    53875                      0.042
# 44            Utah                    63383                      0.036
# 45         Vermont                    60708                      0.037
# 46        Virginia                    66155                      0.043
# 47      Washington                    59068                      0.052
# 48   West Virginia                    39552                      0.073
# 49       Wisconsin                    58080                      0.043
# 50         Wyoming                    55690                      0.040
#
#     share_population_in_metro_areas  share_population_with_high_school_degree  \
# 0                              0.64                                     0.821
# 1                              0.63                                     0.914
# 2                              0.90                                     0.842
# 3                              0.69                                     0.824
# 4                              0.97                                     0.806
# 5                              0.80                                     0.893
# 6                              0.94                                     0.886
# 7                              0.90                                     0.874
# 9                              0.96                                     0.853
# 10                             0.82                                     0.839
# 11                             0.76                                     0.904
# 12                             0.70                                     0.884
# 13                             0.90                                     0.864
# 14                             0.79                                     0.866
# 15                             0.60                                     0.914
# 16                             0.64                                     0.897
# 17                             0.56                                     0.817
# 18                             0.81                                     0.822
# 19                             0.54                                     0.902
# 20                             0.97                                     0.890
# 21                             0.97                                     0.890
# 22                             0.87                                     0.879
# 23                             0.75                                     0.915
# 24                             0.45                                     0.804
# 25                             0.78                                     0.868
# 26                             0.34                                     0.908
# 27                             0.60                                     0.898
# 28                             0.87                                     0.839
# 29                             0.63                                     0.913
# 30                             1.00                                     0.874
# 31                             0.69                                     0.828
# 32                             0.94                                     0.847
# 33                             0.76                                     0.843
# 34                             0.50                                     0.901
# 35                             0.75                                     0.876
# 36                             0.59                                     0.856
# 37                             0.87                                     0.891
# 38                             0.87                                     0.879
# 39                             1.00                                     0.847
# 40                             0.79                                     0.836
# 41                             0.51                                     0.899
# 42                             0.82                                     0.831
# 43                             0.92                                     0.799
# 44                             0.82                                     0.904
# 45                             0.35                                     0.910
# 46                             0.89                                     0.866
# 47                             0.86                                     0.897
# 48                             0.55                                     0.828
# 49                             0.69                                     0.898
# 50                             0.31                                     0.918
#
#     share_non_citizen  share_white_poverty  gini_index  share_non_white  \
# 0                0.02                 0.12       0.472             0.35
# 1                0.04                 0.06       0.422             0.42
# 2                0.10                 0.09       0.455             0.49
# 3                0.04                 0.12       0.458             0.26
# 4                0.13                 0.09       0.471             0.61
# 5                0.06                 0.07       0.457             0.31
# 6                0.06                 0.06       0.486             0.30
# 7                0.05                 0.08       0.440             0.37
# 9                0.09                 0.11       0.474             0.46
# 10               0.08                 0.09       0.468             0.48
# 11               0.08                 0.07       0.433             0.81
# 12               0.04                 0.11       0.433             0.16
# 13               0.07                 0.07       0.465             0.37
# 14               0.03                 0.12       0.440             0.20
# 15               0.03                 0.09       0.427             0.15
# 16               0.04                 0.11       0.445             0.25
# 17               0.03                 0.17       0.466             0.15
# 18               0.02                 0.12       0.475             0.42
# 19                NaN                 0.12       0.437             0.09
# 20               0.08                 0.06       0.443             0.50
# 21               0.09                 0.08       0.475             0.27
# 22               0.04                 0.09       0.451             0.24
# 23               0.05                 0.05       0.440             0.18
# 24                NaN                 0.14       0.468             0.44
# 25               0.02                 0.07       0.455             0.20
# 26               0.01                 0.10       0.435             0.10
# 27               0.05                 0.07       0.432             0.21
# 28               0.10                 0.08       0.448             0.50
# 29               0.03                 0.06       0.425             0.09
# 30               0.11                 0.07       0.464             0.44
# 31               0.06                 0.10       0.464             0.62
# 32               0.10                 0.10       0.499             0.42
# 33               0.05                 0.10       0.464             0.38
# 34               0.03                 0.09       0.433             0.15
# 35               0.03                 0.10       0.452             0.21
# 36               0.04                 0.10       0.454             0.35
# 37               0.07                 0.10       0.449             0.26
# 38               0.03                 0.09       0.461             0.24
# 39               0.08                 0.08       0.467             0.28
# 40               0.03                 0.09       0.461             0.36
# 41                NaN                 0.08       0.442             0.17
# 42               0.04                 0.13       0.468             0.27
# 43               0.11                 0.08       0.469             0.56
# 44               0.04                 0.08       0.419             0.19
# 45               0.01                 0.10       0.444             0.06
# 46               0.06                 0.07       0.459             0.38
# 47               0.08                 0.09       0.441             0.31
# 48               0.01                 0.14       0.451             0.07
# 49               0.03                 0.09       0.430             0.22
# 50               0.02                 0.09       0.423             0.15
#
#     share_voters_voted_trump  hate_crimes_per_100k_splc  \
# 0                       0.63                   0.125839
# 1                       0.53                   0.143740
# 2                       0.50                   0.225320
# 3                       0.60                   0.069061
# 4                       0.33                   0.255805
# 5                       0.44                   0.390523
# 6                       0.41                   0.335392
# 7                       0.42                   0.322754
# 9                       0.49                   0.187521
# 10                      0.51                   0.120420
# 11                      0.30                        NaN
# 12                      0.59                   0.124208
# 13                      0.39                   0.195345
# 14                      0.57                   0.247009
# 15                      0.52                   0.454427
# 16                      0.57                   0.105152
# 17                      0.63                   0.324397
# 18                      0.58                   0.109733
# 19                      0.45                   0.615574
# 20                      0.35                   0.370439
# 21                      0.34                   0.630811
# 22                      0.48                   0.403779
# 23                      0.45                   0.627480
# 24                      0.58                   0.067447
# 25                      0.57                   0.184524
# 26                      0.57                   0.495491
# 27                      0.60                   0.159490
# 28                      0.46                   0.141673
# 29                      0.47                   0.151550
# 30                      0.42                   0.078306
# 31                      0.40                   0.294811
# 32                      0.37                   0.350620
# 33                      0.51                   0.244007
# 34                      0.64                        NaN
# 35                      0.52                   0.190714
# 36                      0.65                   0.133629
# 37                      0.41                   0.832850
# 38                      0.49                   0.285101
# 39                      0.40                   0.095402
# 40                      0.55                   0.209894
# 41                      0.62                        NaN
# 42                      0.61                   0.199938
# 43                      0.53                   0.213584
# 44                      0.47                   0.136547
# 45                      0.33                   0.324149
# 46                      0.45                   0.363249
# 47                      0.38                   0.677488
# 48                      0.69                   0.328677
# 49                      0.48                   0.226197
# 50                      0.70                        NaN
#
#     avg_hatecrimes_per_100k_fbi
# 0                      1.806410
# 1                      1.656700
# 2                      3.413928
# 3                      0.869209
# 4                      2.397986
# 5                      2.804689
# 6                      3.772701
# 7                      1.469980
# 9                      0.698070
# 10                     0.412012
# 11                          NaN
# 12                     1.891331
# 13                     1.044016
# 14                     1.757357
# 15                     0.561396
# 16                     2.143987
# 17                     4.207890
# 18                     1.341170
# 19                     2.626611
# 20                     1.324840
# 21                     4.801899
# 22                     3.200442
# 23                     3.612412
# 24                     0.622746
# 25                     1.908955
# 26                     2.954959
# 27                     2.686248
# 28                     2.113990
# 29                     2.105989
# 30                     4.413203
# 31                     1.886435
# 32                     3.102164
# 33                     1.262680
# 34                     4.741070
# 35                     3.240420
# 36                     1.081672
# 37                     3.394886
# 38                     0.430928
# 39                     1.282572
# 40                     1.937083
# 41                     3.301737
# 42                     3.136051
# 43                     0.752768
# 44                     2.384065
# 45                     1.903081
# 46                     1.724755
# 47                     3.817740
# 48                     2.037054
# 49                     1.121945
# 50                     0.266941

# %%
for col in hate.columns:
    print(hate[col].describe())
# Out:
# count            50
# unique           50
# top       Minnesota
# freq              1
# Name: state, dtype: object
# count       50.000000
# mean     54962.540000
# std       9109.318667
# min      35521.000000
# 25%      48358.500000
# 50%      54613.000000
# 75%      60652.750000
# max      76165.000000
# Name: median_household_income, dtype: float64
# count    50.00000
# mean      0.04922
# std       0.01051
# min       0.02800
# 25%       0.04200
# 50%       0.05050
# 75%       0.05700
# max       0.07300
# Name: share_unemployed_seasonal, dtype: float64
# count    50.000000
# mean      0.745200
# std       0.179855
# min       0.310000
# 25%       0.630000
# 50%       0.785000
# 75%       0.885000
# max       1.000000
# Name: share_population_in_metro_areas, dtype: float64
# count    50.000000
# mean      0.869080
# std       0.034418
# min       0.799000
# 25%       0.839750
# 50%       0.875000
# 75%       0.898000
# max       0.918000
# Name: share_population_with_high_school_degree, dtype: float64
# count    47.000000
# mean      0.053404
# std       0.030308
# min       0.010000
# 25%       0.030000
# 50%       0.040000
# 75%       0.080000
# max       0.130000
# Name: share_non_citizen, dtype: float64
# count    50.000000
# mean      0.092800
# std       0.023822
# min       0.050000
# 25%       0.080000
# 50%       0.090000
# 75%       0.100000
# max       0.170000
# Name: share_white_poverty, dtype: float64
# count    50.00000
# mean      0.45220
# std       0.01783
# min       0.41900
# 25%       0.44000
# 50%       0.45300
# 75%       0.46575
# max       0.49900
# Name: gini_index, dtype: float64
# count    50.000000
# mean      0.309400
# std       0.160298
# min       0.060000
# 25%       0.192500
# 50%       0.275000
# 75%       0.420000
# max       0.810000
# Name: share_non_white, dtype: float64
# count    50.000000
# mean      0.499000
# std       0.100818
# min       0.300000
# 25%       0.420000
# 50%       0.495000
# 75%       0.577500
# max       0.700000
# Name: share_voters_voted_trump, dtype: float64
# count    46.000000
# mean      0.277610
# std       0.177723
# min       0.067447
# 25%       0.142190
# 50%       0.225759
# 75%       0.346813
# max       0.832850
# Name: hate_crimes_per_100k_splc, dtype: float64
# count    49.000000
# mean      2.192391
# std       1.196972
# min       0.266941
# 25%       1.282572
# 50%       1.937083
# 75%       3.136051
# max       4.801899
# Name: avg_hatecrimes_per_100k_fbi, dtype: float64

# %%
df_jittered = hate.loc[:, 'median_household_income':'hate_crimes_per_100k_splc']

jitter = pd.DataFrame(
    np.random.uniform(0, 1, size=(df_jittered.shape)),
    columns=df_jittered.columns
)

df_jittered = df_jittered.add(jitter)

# %%
# Declare that you want to make a scatterplot matrix.
g = sns.PairGrid(df_jittered.dropna(), diag_sharey=False)
# Scatterplot.
g.map_upper(plt.scatter, alpha=.5)
# Fit line summarizing the linear relationship of the two variables.
g.map_lower(sns.regplot, scatter_kws=dict(alpha=0))
# Give information about the univariate distributions of the variables.
g.map_diag(sns.kdeplot, lw=3)
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
corrmat = hate.corr()
print(corrmat)
f, ax = plt.subplots(figsize=(12, 9))

sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()
# Out:
#                                           median_household_income  \
# median_household_income                                  1.000000
# share_unemployed_seasonal                               -0.445023
# share_population_in_metro_areas                          0.256924
# share_population_with_high_school_degree                 0.665700
# share_non_citizen                                        0.263097
# share_white_poverty                                     -0.810619
# gini_index                                              -0.347002
# share_non_white                                          0.051640
# share_voters_voted_trump                                -0.592600
# hate_crimes_per_100k_splc                                0.286921
# avg_hatecrimes_per_100k_fbi                              0.242131
#
#                                           share_unemployed_seasonal  \
# median_household_income                                   -0.445023
# share_unemployed_seasonal                                  1.000000
# share_population_in_metro_areas                            0.327591
# share_population_with_high_school_degree                  -0.640613
# share_non_citizen                                          0.230768
# share_white_poverty                                        0.300708
# gini_index                                                 0.507687
# share_non_white                                            0.393770
# share_voters_voted_trump                                  -0.027138
# hate_crimes_per_100k_splc                                 -0.131505
# avg_hatecrimes_per_100k_fbi                               -0.141360
#
#                                           share_population_in_metro_areas  \
# median_household_income                                          0.256924
# share_unemployed_seasonal                                        0.327591
# share_population_in_metro_areas                                  1.000000
# share_population_with_high_school_degree                        -0.275781
# share_non_citizen                                                0.733352
# share_white_poverty                                             -0.349272
# gini_index                                                       0.495798
# share_non_white                                                  0.523791
# share_voters_voted_trump                                        -0.563241
# hate_crimes_per_100k_splc                                        0.024239
# avg_hatecrimes_per_100k_fbi                                      0.099868
#
#                                           share_population_with_high_school_degree  \
# median_household_income                                                   0.665700
# share_unemployed_seasonal                                                -0.640613
# share_population_in_metro_areas                                          -0.275781
# share_population_with_high_school_degree                                  1.000000
# share_non_citizen                                                        -0.289332
# share_white_poverty                                                      -0.515259
# gini_index                                                               -0.705735
# share_non_white                                                          -0.454158
# share_voters_voted_trump                                                 -0.180064
# hate_crimes_per_100k_splc                                                 0.421476
# avg_hatecrimes_per_100k_fbi                                               0.226098
#
#                                           share_non_citizen  \
# median_household_income                            0.263097
# share_unemployed_seasonal                          0.230768
# share_population_in_metro_areas                    0.733352
# share_population_with_high_school_degree          -0.289332
# share_non_citizen                                  1.000000
# share_white_poverty                               -0.336194
# gini_index                                         0.416602
# share_non_white                                    0.712812
# share_voters_voted_trump                          -0.603599
# hate_crimes_per_100k_splc                          0.071225
# avg_hatecrimes_per_100k_fbi                        0.160065
#
#                                           share_white_poverty  gini_index  \
# median_household_income                             -0.810619   -0.347002
# share_unemployed_seasonal                            0.300708    0.507687
# share_population_in_metro_areas                     -0.349272    0.495798
# share_population_with_high_school_degree            -0.515259   -0.705735
# share_non_citizen                                   -0.336194    0.416602
# share_white_poverty                                  1.000000    0.238886
# gini_index                                           0.238886    1.000000
# share_non_white                                     -0.204771    0.397116
# share_voters_voted_trump                             0.487233   -0.171656
# hate_crimes_per_100k_splc                           -0.098852   -0.113394
# avg_hatecrimes_per_100k_fbi                         -0.061167    0.056132
#
#                                           share_non_white  \
# median_household_income                          0.051640
# share_unemployed_seasonal                        0.393770
# share_population_in_metro_areas                  0.523791
# share_population_with_high_school_degree        -0.454158
# share_non_citizen                                0.712812
# share_white_poverty                             -0.204771
# gini_index                                       0.397116
# share_non_white                                  1.000000
# share_voters_voted_trump                        -0.422068
# hate_crimes_per_100k_splc                       -0.267217
# avg_hatecrimes_per_100k_fbi                     -0.214774
#
#                                           share_voters_voted_trump  \
# median_household_income                                  -0.592600
# share_unemployed_seasonal                                -0.027138
# share_population_in_metro_areas                          -0.563241
# share_population_with_high_school_degree                 -0.180064
# share_non_citizen                                        -0.603599
# share_white_poverty                                       0.487233
# gini_index                                               -0.171656
# share_non_white                                          -0.422068
# share_voters_voted_trump                                  1.000000
# hate_crimes_per_100k_splc                                -0.417698
# avg_hatecrimes_per_100k_fbi                              -0.173189
#
#                                           hate_crimes_per_100k_splc  \
# median_household_income                                    0.286921
# share_unemployed_seasonal                                 -0.131505
# share_population_in_metro_areas                            0.024239
# share_population_with_high_school_degree                   0.421476
# share_non_citizen                                          0.071225
# share_white_poverty                                       -0.098852
# gini_index                                                -0.113394
# share_non_white                                           -0.267217
# share_voters_voted_trump                                  -0.417698
# hate_crimes_per_100k_splc                                  1.000000
# avg_hatecrimes_per_100k_fbi                                0.474420
#
#                                           avg_hatecrimes_per_100k_fbi
# median_household_income                                      0.242131
# share_unemployed_seasonal                                   -0.141360
# share_population_in_metro_areas                              0.099868
# share_population_with_high_school_degree                     0.226098
# share_non_citizen                                            0.160065
# share_white_poverty                                         -0.061167
# gini_index                                                   0.056132
# share_non_white                                             -0.214774
# share_voters_voted_trump                                    -0.173189
# hate_crimes_per_100k_splc                                    0.474420
# avg_hatecrimes_per_100k_fbi                                  1.000000

# %% [markdown]
# it appears from the above data that judging by absolute values, the highest correlation between Hate Crimes (per 100k) recorded by  the SPLC, are features such as (in descending order): "avg_hatecrimes_per_100k_fbi", "share_population_with_high_school_degree", "share_voters_voted_trump" and "median_household_income"

# %%
income = [hate['median_household_income']]
crime_rate = [hate['hate_crimes_per_100k_splc']]

# %%
g = sns.lmplot(y='median_household_income', # Variable 1.
               x='hate_crimes_per_100k_splc',
               data=hate, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("Median Income in USD")
g.set_xlabels("Hate Crimes per 100k (SPLC) ")
plt.title('Income per Crime Rate')
plt.show()

# %%
g = sns.lmplot(y='share_voters_voted_trump', # Variable 1.
               x='hate_crimes_per_100k_splc',
               data=hate, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("Citizens who voted for President Trump")
g.set_xlabels("Hate Crimes per 100k (SPLC) ")
plt.title('Income per Crime Rate')
plt.show()

# %%
g = sns.lmplot(y='gini_index', # Variable 1.
               x='hate_crimes_per_100k_splc',
               data=hate, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("Median Income in USD")
g.set_xlabels("Hate Crimes per 100k (SPLC) ")
plt.title('Income per Crime Rate')
plt.show()

# %%
g = sns.lmplot(y='share_non_citizen', # Variable 1.
               x='hate_crimes_per_100k_splc',
               data=hate, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("Median Income in USD")
g.set_xlabels("Hate Crimes per 100k (SPLC) ")
plt.title('Income per Crime Rate')
plt.show()

# %%
g = sns.lmplot(y='share_population_with_high_school_degree', # Variable 1.
               x='hate_crimes_per_100k_splc',
               data=hate, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("Median Income in USD")
g.set_xlabels("Hate Crimes per 100k (SPLC) ")
plt.title('Income per Crime Rate')
plt.show()

# %%
crime1 = hate[["hate_crimes_per_100k_splc", "share_population_with_high_school_degree", "share_non_citizen","gini_index"]]

# %%
state_crime1 = hate.sort_values('avg_hatecrimes_per_100k_fbi',ascending=False)
sns.set(style="darkgrid")
g = sns.factorplot(x="avg_hatecrimes_per_100k_fbi", y="state", hue=None, data=state_crime1,
                   size=10, kind="bar", palette="pastel", ci=95)
g.despine(left=True)
g.set_ylabels("state")
g.set_xlabels("crime rate")
plt.title('Crime Rate by State (FBI) ')
plt.show()
sns.set(style="darkgrid")

state_crime2 = hate.sort_values('hate_crimes_per_100k_splc',ascending=False)
g = sns.factorplot(x="hate_crimes_per_100k_splc", y="state", hue=None, data=state_crime2,
                   size=10, kind="bar", palette="pastel", ci=95)
g.despine(left=True)
g.set_ylabels("state")
g.set_xlabels("crime rate")
plt.title('Crime Rate by State (SPLC) ')
plt.show()
